# %%
import matplotlib.pyplot as plt
import pandas as pd

# Leer el archivo de datos
data = pd.read_csv('Registro1_OpenBCI.txt', skiprows=6)

# Obtener las señales EEG
eeg = data.iloc[:, 1:9].values

# Crear una figura y un conjunto de ejes
fig, ax = plt.subplots()

# Plotea las señales EEG
ax.plot(eeg)

# Establecer etiquetas de los ejes
ax.set_xlabel('Muestras')
ax.set_ylabel('Amplitud (uV)')

# Agregar leyenda para cada canal
ax.legend(['Canal 1', 'Canal 2', 'Canal 3', 'Canal 4', 'Canal 5', 'Canal 6', 'Canal 7', 'Canal 8'])

# Mostrar el gráfico
plt.show()

# Obtener las señales
signals = data.iloc[:, 9:17].values

# Crear una figura y un conjunto de ejes para cada señal
fig, ax = plt.subplots(8, 1, figsize=(10, 12), sharex=True)

# Iterar sobre cada señal y plotearla en su respectivo eje
for i in range(8):
    ax[i].plot(signals[:, i])
    ax[i].set_ylabel('Amplitud (uV)')
    ax[i].set_title(f'Señal {i+1}')
    ax[i].legend([f'Señal {i+1}'])

# Establecer etiquetas del eje x
ax[-1].set_xlabel('Muestras')

# Mostrar el gráfico
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_43668\1271836250.py in <module>
#       3
#       4 # Leer el archivo de datos
# ----> 5 data = pd.read_csv('Registro1_OpenBCI.txt', skiprows=6)
#       6
#       7 # Obtener las señales EEG
#
# c:\Users\mauri\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Leer el archivo de datos
data = pd.read_csv('Registro2_OpenBCI.txt', skiprows=6)

# Obtener las señales EEG
eeg = data.iloc[:, 1:9].values

# Crear una figura y un conjunto de ejes
fig, ax = plt.subplots()

# Plotea las señales EEG
ax.plot(eeg)

# Establecer etiquetas de los ejes
ax.set_xlabel('Muestras')
ax.set_ylabel('Amplitud (uV)')

# Agregar leyenda para cada canal
ax.legend(['Canal 1', 'Canal 2', 'Canal 3', 'Canal 4', 'Canal 5', 'Canal 6', 'Canal 7', 'Canal 8'])

# Mostrar el gráfico
plt.show()
# Obtener las señales
signals = data.iloc[:, 9:17].values

# Crear una figura y un conjunto de ejes para cada señal
fig, ax = plt.subplots(8, 1, figsize=(10, 12), sharex=True)

# Iterar sobre cada señal y plotearla en su respectivo eje
for i in range(8):
    ax[i].plot(signals[:, i])
    ax[i].set_ylabel('Amplitud (uV)')
    ax[i].set_title(f'Señal {i+1}')
    ax[i].legend([f'Señal {i+1}'])

# Establecer etiquetas del eje x
ax[-1].set_xlabel('Muestras')

# Mostrar el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Leer el archivo de datos
data = pd.read_csv('Registro3_OpenBCI.txt', skiprows=6)

# Obtener las señales EEG
eeg = data.iloc[:, 1:9].values

# Crear una figura y un conjunto de ejes
fig, ax = plt.subplots()

# Plotea las señales EEG
ax.plot(eeg)

# Establecer etiquetas de los ejes
ax.set_xlabel('Muestras')
ax.set_ylabel('Amplitud (uV)')

# Agregar leyenda para cada canal
ax.legend(['Canal 1', 'Canal 2', 'Canal 3', 'Canal 4', 'Canal 5', 'Canal 6', 'Canal 7', 'Canal 8'])

# Mostrar el gráfico
plt.show()

# Obtener las señales
signals = data.iloc[:, 9:17].values

# Crear una figura y un conjunto de ejes para cada señal
fig, ax = plt.subplots(8, 1, figsize=(10, 12), sharex=True)

# Iterar sobre cada señal y plotearla en su respectivo eje
for i in range(8):
    ax[i].plot(signals[:, i])
    ax[i].set_ylabel('Amplitud (uV)')
    ax[i].set_title(f'Señal {i+1}')
    ax[i].legend([f'Señal {i+1}'])

# Establecer etiquetas del eje x
ax[-1].set_xlabel('Muestras')

# Mostrar el gráfico
plt.show()
